# %%
import pandas as pd

# %%
f1_results = pd.read_csv(r"E:\Documentos\IT\Projects\Formula 1 projects\Data\results.csv")

# %%
f1_results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
f1_races = pd.read_csv(r"E:\Documentos\IT\Projects\Formula 1 projects\Data\races.csv")

# %%
f1_races.head(40)
# Out:
#     raceId  year  round  circuitId                   name        date  \
# 0        1  2009      1          1  Australian Grand Prix  2009-03-29
# 1        2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2        3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3        4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4        5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5        6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6        7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7        8  2009      8          9     British Grand Prix  2009-06-21
# 8        9  2009      9         20      German Grand Prix  2009-07-12
# 9       10  2009     10         11   Hungarian Grand Prix  2009-07-26
# 10      11  2009     11         12    European Grand Prix  2009-08-23
# 11      12  2009     12         13     Belgian Grand Prix  2009-08-30
# ...

# %%
f1_2008_championship = f1_results[(f1_results["raceId"] >= 18) & (f1_results["raceId"] <= 35)]

# %%
f1_2008_championship.sort_values("driverId").head(50)
# Out:
#      resultId  raceId  driverId  constructorId number  grid position  \
# 0           1      18         1              1     22     1        1
# 319       320      33         1              1     22     1       12
# 56         57      20         1              1     22     3       13
# 26         27      19         1              1     22     9        5
# 68         69      21         1              1     22     5        3
# 290       291      32         1              1     22     2        3
# 89         90      22         1              1     22     3        2
# 352       353      35         1              1     22     4        5
# 274       275      31         1              1     22    15        7
# 328       329      34         1              1     22     1        1
# 250       251      30         1              1     22     1        3
# 108       109      23         1              1     22     3        1
# 188       189      27         1              1     22     1        1
# ...

# %%
hamilton_total_points = 0
if f1_2008_championship["driverId"] == 1:
    hamilton_total_points += f1_2008_championship["points"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 hamilton_total_points = 0
# ----> 2 if f1_2008_championship["driverId"] == 1:
#       3     hamilton_total_points += f1_2008_championship["points"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(hamilton_total_points)
